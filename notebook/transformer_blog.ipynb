# %% [markdown]
# #  Understanding Transformers and Hugging Face

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### what is NLP
#
# Natural Language Processing (NLP) is a subfield of artificial intelligence (AI) that focuses on the interaction between computers and humans through natural language. The primary objective of NLP is to enable computers to understand, interpret, and generate human languages in a way that is both meaningful and useful. This involves a combination of linguistics, computer science, and machine learning. NLP allows machines to perform a variety of tasks such as language translation, sentiment analysis, speech recognition, and text generation.

# %% [markdown]
# ### Limitations of RNNs and LSTMs
#
#
# Recurrent Neural Networks (RNNs)
#
# RNNs are neural networks built specifically for handling sequential data. Unlike traditional feedforward networks they have loops that let them keep information from previous steps. This makes them useful for tasks where current outputs depend on earlier inputs like language modeling or predicting the next word.
#
# The basic structure includes:
#
#     Input Layer: Receives the sequence data.
#     Hidden Layer: Processes input and maintains information from earlier time steps through recurrent connections.
#     Output Layer: Generates predictions based on the current hidden state.
#
# RNNs perform well on short sequences but struggle to capture long-range dependencies due to their limited memory.
#
# ![image_rnn](../images/RNN.png)
#
# Limitations of RNNs
#
# The main limitation of RNNs is the vanishing gradient problem. As sequences grow longer they struggle to remember information from earlier steps. This makes them less effective for tasks that need understanding of long-term dependencies like machine translation or speech recognition. To resolve these challenges more advanced models such as LSTM networks were developed.
#
#
#
#
# Long Short-Term Memory (LSTM) Networks
#
# LSTM networks are an improved version of RNNs designed to solve the vanishing gradient problem. They use memory cells that keep information over longer periods.
#
# LSTMs have special gates to control the flow of information:
#
#     Input Gate: Decides what new information to store.
#     Forget Gate: Chooses what information to remove.
#     Output Gate: Decides what information to pass on.
#
# This gating system allows LSTMs to remember and forget information selectively helps in making them effective at learning long-term dependencies.
#
# They work well in tasks like sentiment analysis, speech recognition and language translation where understanding context over long sequences is important.
#
#
# ![LSTM](../images/LSTM.png)
#
#
# Limitations of LSTMs
#
# They are more complex than RNNs which makes them slower to train and demands more memory. Despite handling longer sequences better they still face challenges with very long-range dependencies. Their sequential nature also limits the ability to process data in parallel which slows down training.

# %% [markdown]
# ## Why Transformers were introduced
#
#
#
# While LSTMs and GRUs improved on basic RNNs, they still had major drawbacks. Their step-by-step sequential processing made it difficult to handle very long sequences and complex dependencies efficiently. This sequential nature also limited parallelization which causes slow and costly training.
#
# Transformers solved these problems by using self-attention which processes the entire sequence at once. This allows transformers to capture long-range dependencies more effectively and train much faster. Unlike RNN-based models, transformers do not rely on sequential steps helps in making them highly scalable and suitable for larger datasets and more complex tasks.
#
#
# ![transformer](../images/Transformer.png)

# %% [markdown]
# ## The significance of the Attention Is All You Need paper
#
# The paper Attention Is All You Need, published in 2017 by researchers at Google, marked a major breakthrough in the field of Natural Language Processing (NLP). Prior to this work, sequence modeling tasks such as machine translation primarily relied on Recurrent Neural Networks (RNNs) and Long Short-Term Memory (LSTM) networks, which processed data sequentially and struggled with long-range dependencies. The paper introduced the Transformer architecture, which replaced recurrence entirely with a self-attention mechanism. By allowing the model to process all tokens in a sequence simultaneously and focus on the most relevant parts of the input, Transformers achieved better performance while significantly reducing training time. This innovation not only advanced machine translation but also laid the foundation for modern language models such as BERT, GPT, and T5, making it one of the most influential research papers in artificial intelligence.
#
# Key Contributions of the Paper
#
# Introduced the Transformer architecture, eliminating the need for recurrent neural networks.
# Proposed the self-attention mechanism as the core method for capturing contextual relationships between words.
# Enabled parallel processing of input sequences, leading to faster and more efficient training.
# Improved the handling of long-range dependencies compared to RNNs and LSTMs.
# Achieved state-of-the-art performance on machine translation benchmarks at the time.
# Established the foundation for modern large language models (LLMs) and generative AI systems.
# Influenced a wide range of applications, including machine translation, text summarization, question answering, and conversational AI.
# Why It Matters Today
#
# Nearly every major breakthrough in modern NLP and Generative AI can trace its roots back to the Transformer architecture introduced in Attention Is All You Need. Models powering applications such as chatbots, language translation systems, content generation tools, and coding assistants are all built upon concepts first introduced in this paper. As a result, the publication is widely regarded as one of the most impactful papers in the history of deep learning and artificial intelligence.
#
# [paper link](https://arxiv.org/abs/1706.03762)

# %% [markdown]
# ##  Transformer Architecture
#
#
# Transformers are a type of deep learning model that utilizes self-attention mechanisms to process and generate sequences of data efficiently. They capture long-range dependencies and contextual relationships making them highly effective for tasks like language modeling, machine translation and text generation. Transformer model is built on encoder-decoder architecture where both the encoder and decoder are composed of a series of layers that utilize self-attention mechanisms and feed-forward neural networks. This architecture enables the model to process input data in parallel making it highly efficient and effective for tasks involving sequential data.
#
#
# The encoder processes input sequences and creates meaningful representations.
# The decoder generates outputs based on encoder representations and previously predicted tokens.
#
#
# 1. Encoder
#
# The primary function of the encoder is to create a high-dimensional representation of the input sequence that the decoder can use to generate the output. Encoder consists of multiple layers and each layer is composed of two main sub-layers:
#
#     Self-Attention Mechanism: This sub-layer allows the encoder to weigh the importance of different parts of the input sequence differently to capture dependencies regardless of their distance within the sequence.
#     Feed-Forward Neural Network: This sub-layer consists of two linear transformations with a ReLU activation in between. It processes the output of the self-attention mechanism to generate a refined representation.
#
# Layer normalization and residual connections are used around each of these sub-layers to ensure stability and improve convergence during training.
#
# ![encoder](../images/encoder.png)
# 2. Decoder
#
# Decoder in transformer also consists of multiple identical layers. Its primary function is to generate the output sequence based on the representations provided by the encoder and the previously generated tokens of the output.
#
# Each decoder layer consists of three main sub-layers:
#
#     Masked Self-Attention Mechanism: Similar to the encoder's self-attention mechanism but its main purpose is to prevent attending to future tokens to maintain the autoregressive property (no cheating during generation).
#     Encoder-Decoder Attention Mechanism: This sub-layer allows the decoder to focus on relevant parts of the encoder's output representation. This allows the decoder to focus on relevant parts of the input, essential for tasks like translation.
#     Feed-Forward Neural Network: This sub-layer processes the combined output of the masked self-attention and encoder-decoder attention mechanisms.
#
# ![decoder](../images/decoder.png)
#
#
# In-Depth Analysis of Transformer Components
# 1. Multi-Head Self-Attention Mechanism
#
# Multi-head attention extends the self-attention mechanism by applying it multiple times in parallel with each "head" learning different aspects of the input data. This allows the model to capture a richer set of relationships within the input sequence. The outputs of these heads are then concatenated and linearly transformed to produce the final output. The benefits include:
#
#     Improved ability to capture complex patterns in the data.
#     Enhanced model capacity without significant increase in computational complexity.
#
#     Each word in a sequence is mapped to three vectors:
#
#     Query (Q)
#     Key (K)
#     Value (V)
#
# Attention scores are computed as: Attention(Q,K,V)=softmax(QKTdk)VAttention(Q,K,V)=softmax(dk​
# ​QKT​)V
#
# These scores determine how much attention each word should pay to others.
#
# 2. Position-wise Feed-Forward Networks
#
# Each position in the sequence is independently processed using a feed-forward network:
#
#     FFN(x)=max⁡(0,xW1+b1)W2+b2
#     FFN(x)=max(0,xW1​+b1​)W2​+b2​
#
# This helps the transformer learn complex representations of input features.
#
#     Note: This is a two-layer fully connected network applied position-wise.
#
# 3. Positional Encoding
#
#     Transformers lack inherent information about the order of the input sequence due to their parallel processing nature. Positional encoding is introduced to provide the model with information about the position of each token in the sequence.
#     Positional encodings are added to the input embeddings to give the model a sense of token order. These encodings can be either learned or fixed.
#
# 4. Layer Normalization and Residual Connections
#
#     Layer Normalization: stabilizes training by normalizing inputs.
#     Residual Connections: help avoid vanishing gradients by adding the original input to the output of the sub-layer by establishing skip connections from inputs to outputs.
#
#     Output=LayerNorm(x+SubLayer(x))
#     Output=LayerNorm(x+SubLayer(x))
#
# This addition helps in preserving the original input information which is crucial for learning complex representations.
#
# ![transformer](../images/Transformer.png)

# %% [markdown]
# ## 3. Hugging Face Model Card Analysis

# %% [markdown]
# ## facebook/mbart-large-50-many-to-many-mmt
#
# [model link](https://huggingface.co/facebook/mbart-large-50-many-to-many-mmt)
#
# For this project, the selected Transformer model is mBART-50 Many-to-Many Multilingual Machine Translation (facebook/mbart-large-50-many-to-many-mmt). The model is available through the Hugging Face Transformers library and is designed to perform direct translation between multiple language pairs without requiring English as an intermediate language.
#
# Architecture
#
# mBART-50 is based on the Transformer Encoder-Decoder architecture introduced in the Attention Is All You Need paper. It is an extension of the original mBART model and consists of:
#
# A Transformer Encoder that processes the input sequence.
# A Transformer Decoder that generates the output sequence.
# Multi-Head Self-Attention layers for capturing contextual relationships.
# Positional Encoding to preserve word order information.
# Feed Forward Networks, Residual Connections, and Layer Normalization for stable and efficient training.
#
# Unlike traditional translation systems that require separate models for each language pair, mBART-50 employs a single multilingual architecture capable of handling translation among fifty languages.
#
# Intended Use Cases
#
# The primary objective of mBART-50 is multilingual machine translation. The model can directly translate text between any supported language pair by specifying the source and target language tokens.
#
# Typical use cases include:
#
# Machine Translation
# Cross-Lingual Communication
# Multilingual Content Generation
# International Customer Support Systems
# Educational Translation Tools
# Multilingual NLP Research
#
# Because the model is built on a sequence-to-sequence Transformer architecture, it can also be adapted for tasks such as summarization and text generation.
#
# Training Data
#
# mBART-50 was developed as an extension of the original mBART model and fine-tuned for multilingual machine translation tasks.
#
# The model was trained using large-scale multilingual corpora covering fifty languages from diverse linguistic families, including:
#
# English
# Arabic
# Hindi
# French
# German
# Chinese
# Japanese
# Korean
# Russian
# Turkish
#
# and many others.
#
# The multilingual pretraining strategy allows the model to learn shared linguistic representations across languages, enabling effective knowledge transfer between high-resource and low-resource languages.
#
# Evaluation Metrics
#
# The model was evaluated primarily on multilingual machine translation benchmarks.
#
# Common evaluation metrics include:
#
# BLEU Score (Bilingual Evaluation Understudy) – measures translation quality by comparing generated translations against human reference translations.
# Translation Accuracy
# Cross-Lingual Transfer Performance
#
# The authors reported strong performance across multiple language pairs, demonstrating that multilingual pretraining significantly improves translation quality.
#
# Limitations and Biases
#
# Although mBART-50 achieves impressive multilingual capabilities, several limitations should be considered:
#
# Limitations
# Translation quality may vary across languages.
# Low-resource languages may receive lower-quality translations compared to high-resource languages.
# Long documents can be truncated due to model input length constraints.
# Generated translations may occasionally omit or alter contextual information.
# Potential Biases
# Biases present in the training corpus may be reflected in model outputs.
# Cultural, linguistic, or regional preferences may appear in translations.
# The model may perform better on languages that have larger training datasets.
#
# As with most large language models, outputs should be reviewed when used in critical applications.
#
# License Information
#
# The model is publicly available through Hugging Face under the licensing terms specified in its repository. Users should consult the official model page before deploying the model in commercial or production environments to ensure compliance with licensing requirements.
#
# Why This Model Was Selected
#
# mBART-50 was selected for this project because it demonstrates one of the most powerful applications of Transformer architectures: multilingual sequence-to-sequence learning. Unlike traditional translation models that focus on a limited number of language pairs, mBART-50 supports direct translation between fifty languages within a single model. This makes it an excellent case study for understanding how Transformer architectures can scale to real-world multilingual NLP applications while maintaining strong translation performance.

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    api_key=os.environ["HF_TOKEN"],
)

result = client.translation(
    src_lang ='russian',
    tgt_lang= 'english',
    text="Меня зовут Вольфганг и я живу в Берлине",
    model="facebook/mbart-large-50-many-to-many-mmt",
)

# %%
result
# Out:
# TranslationOutput(translation_text='My My My Name My My My My Name My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My My Name Wolfgang Wolfgang Wolfgang Wolfgang Wolfgang Wolfgang I I I I Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin Berlin I I I I I I I I I I I Wolf Wolf Wolf Wolf Wolf Wolf Wolfgang Wolfgang Wolfgang Wolfgang Wolfgang Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf Wolf I I I I I I I I I I I I I I I')

# %% [markdown]
# ## 4. Practical Implementation Using AutoClasses

# %% [markdown]
# Text summarization is the process of generating a concise version of a longer document while preserving its key information and overall meaning. In this task, the facebook/bart-large-cnn model was used to perform abstractive text summarization.
#
# Unlike extractive summarization, which selects important sentences directly from the source text, abstractive summarization generates entirely new sentences that capture the essence of the original content in a more natural and human-like way.
#
# The BART (Bidirectional and Auto-Regressive Transformers) model is based on the Transformer Encoder-Decoder architecture. It has been fine-tuned on the CNN/DailyMail dataset, making it highly effective for news summarization and general-purpose text compression tasks.
#
# [model_link](https://huggingface.co/facebook/bart-large-cnn)
#
# To implement this, Hugging Face AutoClasses were used for model loading. AutoClasses automatically select and load the correct architecture, tokenizer, and configuration from the Hugging Face Model Hub, simplifying the process of working with pretrained Transformer models.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "facebook/bart-large-cnn"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("Loaded successfully!")
# Out:
# c:\Users\User\miniconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# [transformers] Please make sure the generation config includes `forced_bos_token_id=0`.
# ...

# %%
ARTICLE = """ New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
Prosecutors said the marriages were part of an immigration scam.
On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.
After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective
Annette Markowski, a police spokeswoman. In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002.
All occurred either in Westchester County, Long Island, New Jersey or the Bronx. She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.
Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages.
Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.
The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'s
Investigation Division. Seven of the men are from so-called "red-flagged" countries, including Egypt, Turkey, Georgia, Pakistan and Mali.
Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.
If convicted, Barrientos faces up to four years in prison.  Her next court appearance is scheduled for May 18.
"""


inputs = tokenizer(
    ARTICLE,
    return_tensors="pt",
    max_length=1024,
    truncation=True
)

summary_ids = model.generate(
    **inputs,
   
    max_length=130,
    min_length=65,
    num_beams=4,
    early_stopping=True
)

summary = tokenizer.decode(
    summary_ids[0],
    skip_special_tokens=True
)

print(summary)
# Out:
# Liana Barrientos, 39, is charged with two counts of offering a false instrument for filing in the first degree. In total, she has been married 10 times, with nine of her marriages occurring between 1999 and 2002. She is believed to still be married to four men, and at one time, she was married to eight men at once.

# %% [markdown]
# Summarization Workflow
#
# The summarization process consists of the following steps:
#
# Tokenize the input text.
# Convert the text into numerical representations understandable by the model.
# Generate a summary using beam search decoding.
# Decode the generated tokens back into human-readable text.
#
# Observations
#
# The generated summary successfully captured the central ideas of the source document while significantly reducing its length. Important information was retained, and the output remained coherent and grammatically correct. The model demonstrated strong abstractive capabilities by rephrasing information instead of merely copying sentences from the original text.
#
# Strengths
#
# Produces fluent and human-readable summaries.
# Retains key information from lengthy documents.
# Generates concise outputs while preserving context.
# Fine-tuned specifically for summarization tasks, resulting in high-quality performance.
# Easy to deploy using Hugging Face AutoClasses.
#
# Limitations
#
# May occasionally omit minor details present in the source text.
# Can generate overly generalized summaries for highly technical content.
# Performance may decrease when processing domain-specific documents not represented in the training data.
# Input length is constrained by the model's maximum token limit.
# Why BART Was Chosen
#
# The facebook/bart-large-cnn model was selected because it is one of the most widely used pretrained models for abstractive text summarization. Its Encoder-Decoder Transformer architecture allows it to understand contextual relationships within long documents and generate coherent summaries. Additionally, its fine-tuning on the CNN/DailyMail dataset makes it particularly effective for producing concise and informative summaries, making it an ideal choice for demonstrating Transformer-based summarization using the Hugging Face ecosystem.

# %% [markdown]
# ## Task 2: Language Translation
#
# Language translation is one of the most powerful applications of Transformer-based models, enabling seamless conversion of text from one language to another while preserving meaning and context. In this task, the facebook/mbart-large-50-many-to-many-mmt model was used to perform multilingual machine translation.
#
# mBART-50 is a sequence-to-sequence Transformer model that extends the original BART architecture to support 50 different languages, allowing direct translation between any supported language pair without requiring English as an intermediate step.
#
# Model Overview
#
# The model follows an Encoder-Decoder Transformer architecture, where:
#
# The Encoder processes the input sentence in the source language.
# The Decoder generates the translated sentence in the target language.
# Language tokens are used to explicitly define both source and target languages.
#
# This makes mBART-50 highly flexible for multilingual translation tasks.
#
# Model Loading Using AutoClasses
#
# The model and tokenizer were loaded using Hugging Face AutoClasses, which automatically handle configuration and architecture selection.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "facebook/mbart-large-50-many-to-many-mmt"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

print("Loaded successfully!")
# Out:
# Loading weights: 100%|██████████| 516/516 [00:00<00:00, 4085.99it/s]
# Loaded successfully!

# %%
hindi_text ="एक हिंदी लेखक के जीवन की सुबह सूचनाओं से और रात उपन्यास से होती है। वह दुपहर से शाम तक ख़राब सिनेमा के असर में रहता है। इस असर में बाहर धूल और भीतर पन्ने उड़ते रहते हैं। यह उड़ान ही है कि महानगर जीवन क"

inputs = tokenizer(
    hindi_text,

    return_tensors="pt",
    max_length=1024,
    truncation=True
)

summary_ids = model.generate(
    **inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"],
    max_length=60,
    min_length=30,
    num_beams=4,
    early_stopping=True
)

summary = tokenizer.decode(
    summary_ids[0],
    skip_special_tokens=True
)

print(summary)
# Out:
# A Hindi writer's life consists of a morning of information and a night of novels. From noon to midnight, he is affected by bad cinema. Outside by dust and inside by flies of pages. It is this flight that makes the metropolitan life

# %% [markdown]
# Translation Workflow
#
# The translation process involves explicitly setting the source language and forcing the target language during generation.
#
# Input Sentence (Source Language)
#
#         ↓
#
# Tokenization + Source Language ID
#
#         ↓
#
# mBART Encoder
#
#         ↓
#
# Decoder (with forced target language token)
#
#         ↓
#
# Translated Output

# %% [markdown]
# Observations
#
# The model produced a fluent and semantically accurate translation, successfully preserving the meaning of the original sentence while adapting it to the target language structure. The output demonstrates the strength of mBART-50 in handling complex multilingual transformations without requiring separate models for each language pair.
#
# During experimentation, it was also observed that specifying the target language token is essential for controlling output language consistency, as the model supports multiple languages simultaneously.
#
# Strengths
# Supports direct translation between 50 languages
# Uses a single unified model for multilingual tasks
# Produces fluent and context-aware translations
# Eliminates the need for multiple language-specific models
# Efficient for cross-lingual NLP applications
# Limitations
# Requires explicit specification of source and target language codes
# Performance varies across language pairs (higher for high-resource languages)
# Can struggle with very long or complex sentences
# Computationally heavier compared to smaller translation models
# Why mBART-50 Was Chosen
#
# The facebook/mbart-large-50-many-to-many-mmt model was selected because it represents one of the most advanced multilingual Transformer architectures available in the Hugging Face ecosystem. Unlike traditional translation systems that rely on bilingual models, mBART-50 enables many-to-many translation within a single unified framework.
#
# This makes it an ideal model for demonstrating the capabilities of modern Transformer-based multilingual NLP systems, aligning perfectly with the objectives of this assignment.

# %% [markdown]
# ## Conclusion
#
# Transformers have fundamentally transformed the field of Natural Language Processing by replacing traditional sequential models with a more efficient and scalable architecture based on self-attention. The introduction of the Attention Is All You Need paper marked a turning point in deep learning, enabling models to process language in parallel while capturing long-range dependencies more effectively.
#
# In this project, the theoretical concepts of Transformer architecture were connected with practical implementations using the Hugging Face Transformers library. The facebook/bart-large-cnn model demonstrated strong performance in abstractive text summarization, effectively compressing long-form text while preserving key information. Meanwhile, the facebook/mbart-large-50-many-to-many-mmt model showcased the power of multilingual Transformer systems by enabling accurate and fluent translation across multiple languages using a single unified architecture.
#
# Through these experiments, it becomes clear that modern NLP systems are not only dependent on architectural innovation but also on large-scale pretraining and transfer learning. Hugging Face AutoClasses further simplified the process of loading and deploying these complex models, making advanced NLP accessible and practical for real-world applications.
#
# Overall, this project highlights how Transformer-based models bridge the gap between research and application, forming the backbone of many modern AI systems used today in translation, summarization, chatbots, and generative AI tools.
